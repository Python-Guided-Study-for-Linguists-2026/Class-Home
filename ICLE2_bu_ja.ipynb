# %% [markdown]
# # Bulgarian vs. Japanese EFL Writing (ICLE2)
# - Na-Rae Han, `naraehan@pitt.edu`
# - April 9, 2026

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
# Set your corpus root: 
corpus_root = "../Sandbox/ICLE2_bu_ja"
 
# Read in the two corpora:
bucor = PlaintextCorpusReader(corpus_root, 'BG.*txt')
jacor = PlaintextCorpusReader(corpus_root, 'JP.*txt')

# %%
print(bucor.fileids())
# Out:
# ['BGSU1001.txt', 'BGSU1002.txt', 'BGSU1003.txt', 'BGSU1004.txt', 'BGSU1005.txt', 'BGSU1006.txt', 'BGSU1007.txt', 'BGSU1008.txt', 'BGSU1009.txt', 'BGSU1010.txt', 'BGSU1011.txt', 'BGSU1012.txt', 'BGSU1013.txt', 'BGSU1014.txt', 'BGSU1015.txt', 'BGSU1016.txt', 'BGSU1017.txt', 'BGSU1018.txt', 'BGSU1019.txt', 'BGSU1020.txt', 'BGSU1021.txt', 'BGSU1022.txt', 'BGSU1023.txt', 'BGSU1024.txt', 'BGSU1025.txt', 'BGSU1026.txt', 'BGSU1027.txt', 'BGSU1028.txt', 'BGSU1029.txt', 'BGSU1030.txt']

# %%
len(bucor.fileids())
# Out:
# 30

# %%
# %pprint
jacor.fileids()
# Out:
# Pretty printing has been turned OFF
# ['JPSW1001.txt', 'JPSW1002.txt', 'JPSW1003.txt', 'JPSW1004.txt', 'JPSW1005.txt', 'JPSW1006.txt', 'JPSW1007.txt', 'JPSW1008.txt', 'JPSW1009.txt', 'JPSW1010.txt', 'JPSW1011.txt', 'JPSW1012.txt', 'JPSW1013.txt', 'JPSW1014.txt', 'JPSW1015.txt', 'JPSW1016.txt', 'JPSW1017.txt', 'JPSW1018.txt', 'JPSW1019.txt', 'JPSW1020.txt', 'JPSW1021.txt', 'JPSW1022.txt', 'JPSW1023.txt', 'JPSW1024.txt', 'JPSW1025.txt', 'JPSW1026.txt', 'JPSW1027.txt', 'JPSW1028.txt', 'JPSW1029.txt', 'JPSW1030.txt']

# %%
len(jacor.fileids())
# Out:
# 30

# %%
bucor.raw(bucor.fileids()[0])
# Out:
# 'It is time, that our society is dominated by industrialization. The prosperity of a country is based on its enormous industrial corporations that are gradually replacing men with machines. Science is highly developed and controls the economy. From the beginning of school life students are expected to master a huge amount of scientific data. Technology is part of our everyday life.\r\nChildren nowadays prefer to play with computers rather than with our parents\' wooden toys. But I think that in our modern world which worships science and technology there is still a place for dreams and imagination.\r\nThere has always been a place for them in man\'s life. Even in the darkness of the Middle Ages when religion confined the human mind in the cage of its dogmas, men dreamt of a better life.\r\nThey dreamt of exploring the unknown depths of earth and sea, of flying into the sky and reaching the stars. Step by step society has freed itself from the restrictions of religion and science has become the dominant power. Nowadays some people see in its dominance a threat to man\'s inclination to dreaming. But man could dream in the darkest past, so why could he not dream now?\r\nMan has always dreamt of going beyond the world he knew. Science has made the unknown world too small but man keeps on dreaming. He turns to books to find his new inspiration. People nowadays read not less than they did in the past. Besides they still create literature which means they are still capable of creating new imaginary worlds. People still use their imagination to paint pictures and to compose music. Art is still alive. And society feels necessity for this art because people enjoy escaping to other worlds, even if they are not real.\r\nMoreover, I cannot imagine that people have lost their ability of creative thinking. People have always had the gift of imagination. I cannot agree with the statement that because of the dominance of science and technology, there is no place for this gift. How would all the technological achievements and scientific breakthroughs been made, if man had not used his imagination? It is because of his imagination and his constant dreaming that man has achieved so much in science. The fact that science never stops developing is a proof that man never stops using his imagination.\r\nI am sure that man keeps on dreaming. There is not much space left to be explored but in every field of human life there will always be some kind of a frontier and people will always dream of going beyond it. Maybe industry has taken the place of nature and maybe romanticism is dead but psychologists go on asking the question: "Whom or what would you like to take with you on a lonely island?" And people go on dreaming that they will spend their lives like Robinson Crusoe with their favourite show-business star, or favourite pet or book but not with their personal computer.\r\n'

# %%
jacor.raw(jacor.fileids()[0])
# Out:
# "I agree greatly this topic mainly because I think that English becomes an official language in the not too distant. Now, many people can speak English or study it all over the world, and so more people will be able to speak English. Before the Japanese fall behind other people, we should be able to speak English, therefore, we must study English not only junior high school students or over but also pupils. Japanese education system is changing such a program. In this way, Japan tries to internationalize rapidly. However, I think this way won't suffice for becoming international humans. To becoming international humans, we should study English not only school but also daily life. If we can do it, we are able to master English conversation. It is important for us to master English honorific words. Without speaking English honorific, we can't speak English. If we speak English without it, it is rude of you, and so we should master proper English. Therefore, we should learn even our daily life.\r\nI have not only mainly reason but also some partly reason. First partly reason is that if we speak English, we can get though to almost people all over the world, ant it is wonderful for me. Because I am able to make for good humun natures, if I can communicate with others who lives in foreign country. These reasons is worth reason why I must study English. By contraries, if we can't speak English, we can communicate with only people who speak Japanese. It is terrible for me, because we can't keep up with the development of the world. So not only adults but also Japanese students need to master English as a second language.\r\nSecond reason is theta people who visit in Japan from another country increase gradually, that is to say, the opportunity to talk to the foreigners increase gradually without notice, so Japanese people should be able to speak an introduction to English conversation, and I hope that, and I wish all Japanese people could be beyond the boundary to all foreigners, but it is the actual circumstances to be able to talk foreigners only partial Japanese people. Therefore, as time went on, the Japanese people should be able to talk them, and the Japanese people who get out into the world should be able to talk them, too.\r\nI agree greatly to need to master English as a second language for Japanese people, and I am certain of that.\r\n"

# %% [markdown]
# ### Getting to know the textual content
# - It was nice to take a look at the very first essay from the two groups, but is there a different way?
# - Let's try random sampling!

# %%
import random
random.choice(bucor.fileids())
# Out:
# 'BGSU1009.txt'

# %%
randf = random.choice(bucor.fileids())
print(randf)
bucor.raw(randf)
# this will print out a random essay out of 30 every time it runs
# Out:
# BGSU1001.txt
# 'It is time, that our society is dominated by industrialization. The prosperity of a country is based on its enormous industrial corporations that are gradually replacing men with machines. Science is highly developed and controls the economy. From the beginning of school life students are expected to master a huge amount of scientific data. Technology is part of our everyday life.\r\nChildren nowadays prefer to play with computers rather than with our parents\' wooden toys. But I think that in our modern world which worships science and technology there is still a place for dreams and imagination.\r\nThere has always been a place for them in man\'s life. Even in the darkness of the Middle Ages when religion confined the human mind in the cage of its dogmas, men dreamt of a better life.\r\nThey dreamt of exploring the unknown depths of earth and sea, of flying into the sky and reaching the stars. Step by step society has freed itself from the restrictions of religion and science has become the dominant power. Nowadays some people see in its dominance a threat to man\'s inclination to dreaming. But man could dream in the darkest past, so why could he not dream now?\r\nMan has always dreamt of going beyond the world he knew. Science has made the unknown world too small but man keeps on dreaming. He turns to books to find his new inspiration. People nowadays read not less than they did in the past. Besides they still create literature which means they are still capable of creating new imaginary worlds. People still use their imagination to paint pictures and to compose music. Art is still alive. And society feels necessity for this art because people enjoy escaping to other worlds, even if they are not real.\r\nMoreover, I cannot imagine that people have lost their ability of creative thinking. People have always had the gift of imagination. I cannot agree with the statement that because of the dominance of science and technology, there is no place for this gift. How would all the technological achievements and scientific breakthroughs been made, if man had not used his imagination? It is because of his imagination and his constant dreaming that man has achieved so much in science. The fact that science never stops developing is a proof that man never stops using his imagination.\r\nI am sure that man keeps on dreaming. There is not much space left to be explored but in every field of human life there will always be some kind of a frontier and people will always dream of going beyond it. Maybe industry has taken the place of nature and maybe romanticism is dead but psychologists go on asking the question: "Whom or what would you like to take with you on a lonely island?" And people go on dreaming that they will spend their lives like Robinson Crusoe with their favourite show-business star, or favourite pet or book but not with their personal computer.\r\n'

# %%
jacor.raw(random.choice(jacor.fileids()))
# Out:
# 'What is the international language? In Japan, we have learned English as a second language. Why do we have to learn it? Most of Japanese have learned English for 6 years from junior high school. However most of them forget which have learned at school after they graduate from school. Because most of them don\'t have opportunities to use English after school. People who don\'t like English said we need not to master English. Because here is Japan. Japanese need not speak English. We can communicate with others by Japanese. Foreigners should speak Japanese in Japan.\r\nI don\'t agree with that. Today many foreigners visit in Japan. And also many Japanese like to travel other countries. If our native language is different from other countries we travel, we couldn\'t communicate with each other. If we can understand their culture, historical background and their mind through communicating. Therefore I think Japanese students should master English as a second language. Why do Japanese students need to master English? I think there are many countries where they can master or learn English as a second language as Japan. And also there are many countries where their mothe tongue is English. For example I visited China last month. The accident happend. The bath in my room was broken. Water could not take out. So I tried to ask how to fix the bath on the phone. I stayed in the hotel which is managed by Japanese company. Therefore I thought the staff in the hotel can speak Japanese. On the phone I asked the man by Japanese. However he couldn\'t understand what I said. He said to me "I can\'t speak Japanese at all. Please say in English or chinese" As I couldn\'t speak Chinese, I told him the problem in my bathroom by English. Because I used English, we could communicate with each other. So the bathroom would be fix.\r\nToday, we begin to teach English in primary school. More internationalize, more we need to master English to communicate with others. There are a lot of languages in the world. To communicate with others, I think English should be, international language in the future: If people in the world can speak English, I think some international problem such as enviromental problems would be solved. Because people can understand their thoughts by communicating in English. By using English as the international language, minunderstanding which happened by having different background culture or language will decrease in the future. So I hope Japanese students need to master English as a second language. To success mastering English, I hope Japanese students begin to learn English as soon as possible.\r\n'

# %%
for f in bucor.fileids():
    print(f, bucor.raw(f)[:100])
# Out:
# BGSU1001.txt It is time, that our society is dominated by industrialization. The prosperity of a country is based
# BGSU1002.txt Nowadays there is a growing interest in higher education and almost every young person wishes to hav
# BGSU1003.txt Once upon a time there lived a beautiful young lady and a handsome young gentleman. They were in lov
# BGSU1004.txt Our educational system in one of the largest in the world. It offers variety, diversity but not flex
# BGSU1005.txt Science, technology and industrialization are the characteristic features of our world. With the int
# BGSU1006.txt As stated, the topic is based on the assumption that a University degree should be practically orien
# BGSU1007.txt Hard, as our modern times are, they make as proud with one thing only: the technical progress we are
# BGSU1008.txt To live means more than simply to exist. Life requires steady nerves and constant fight. The former
# BGSU1009.txt The world we live in is obsessed with the achievements of science, technology and industrialization.
# BGSU1010.txt Most University degrees are too theoretically oriented and thus the students, when leaving the unive
# BGSU1011.txt Most people would probably say that in our modern world, dominated by science and technology, there
# BGSU1012.txt As recent statistics have shown, more and more people in Bulgaria choose to continue their education
# BGSU1013.txt My opinion is light. It is like a balloon. Once it is inflated by a refreshing breath of inspiration
# BGSU1014.txt I am a student of Plato's. I am one of those whom he taught in the garden of Academ. It is Plato's A
# BGSU1015.txt We live in a highly developed society. Almost everything is possible for us and we achieve things ea
# BGSU1016.txt The question of education is a very contradictional one. Education is one of the most important thin
# BGSU1017.txt When people had only their hands and a fur to keep them warm they had a vast space for imagination,
# BGSU1018.txt What is the purpose of knowledge? Living in the end of the twentieth century is both difficult and e
# BGSU1019.txt Unlike technology, science, and people's life style, imagination is not affected by the fruit (or bi
# BGSU1020.txt Education is not only cramming facts into your head to forget them on the day following the exam nei
# BGSU1021.txt No one and nothing can deprive mankind of its innate and outstanding ability to dream Imagination is
# BGSU1022.txt Nowadays education is indispensable for people in order to find their place in the real world. But i
# BGSU1023.txt I believe this statement is true. We should, however, be careful what we mean by "dreaming" and "ima
# BGSU1024.txt It is quite naive to make such a drastic and generalised statement, without at least a few specifica
# BGSU1025.txt "Now, what I want is, Facts. Teach these boys and girls nothing but Facts. Facts alone are wanted in
# BGSU1026.txt To say that it was an easy task to answer this question would be a lie. Not that I don't have an opi
# BGSU1027.txt I've always hated reading science-fiction, althow most of my friends love it and have tried to provo
# BGSU1028.txt For centuries on end men have tried to answer the many questions that exist in the Universe.
# Their
# BGSU1029.txt Most well-respected universities are regarded as such for the opportunities they offer their student
# BGSU1030.txt One of the things that universities nowadays are most criticised for is that the courses offered are

# %%
for f in jacor.fileids():
    print(f, jacor.raw(f)[:100])
# Out:
# JPSW1001.txt I agree greatly this topic mainly because I think that English becomes an official language in the n
# JPSW1002.txt I think it is important to be able to use English. Because English is used by most people in the wor
# JPSW1003.txt I think to master English as a second language is important for us.
# When I was child or junior high
# JPSW1004.txt It is not bad that Japanese students need to master English as a second language, because English is
# JPSW1005.txt To master a second language is better than just knowing one language. But I think it doesn't have to
# JPSW1006.txt I think that Japanese students need to master English as a second language. Because English is spoke
# JPSW1007.txt What is the international language? In Japan, we have learned English as a second language. Why do w
# JPSW1008.txt I think Japanese students should study English to become international citizens. World official lang
# JPSW1009.txt I think lately that English will be indispensable to us for the foreseeable future.I think that grad
# JPSW1010.txt I think that Japanese students need to master English as a second language. Because English is the m
# JPSW1011.txt I think Japanese students need to master English as a second language. There are something why Japan
# JPSW1012.txt I think Japanese students need to master English as a second language and I have some opinion about
# JPSW1013.txt I think that mastering English as a second language is necessary. The reason that I think so is toda
# JPSW1014.txt I think Japanese students need to master English as a second language. Because there are more people
# JPSW1015.txt I agree with the idea that Japanese students need to master English as a second language. I am going
# JPSW1016.txt In my opinion, Japanese students need to master English as a second language. One reason is that now
# JPSW1017.txt Whether Japanese students need to master English as a second language is very difficult question. So
# JPSW1018.txt Japanese people must be thinking that English is the most international language and cool to master.
# JPSW1019.txt I assume if I am reading English newspaper it is because I am interested in learning or improving my
# JPSW1020.txt I think that Japanese students master English is very important, because in future, the world will p
# JPSW1021.txt I think Japanese student need to master English as a second language. One reason is proceeding inter
# JPSW1022.txt It is very important for us to master English as a second language. Because, today in society, there
# JPSW1023.txt There are various kinds of language in the world. Especially, English is spoken by so many people. I
# JPSW1024.txt I think Japanese students need to master English as a second language. Today, you know, English is t
# JPSW1025.txt I think that it is an important process to master English as a second language for Japanese students
# JPSW1026.txt Today, English is spoken at all over the world. So English is an international language now. I think
# JPSW1027.txt I think that it is very important thing to master English as a second language. There are many peopl
# JPSW1028.txt I have studied English since six years ago, so I think my English level become better than the first
# JPSW1029.txt English is international language. Learning English is important, because it is able to communicate
# JPSW1030.txt I agree that we master English as a second language. If you want to learn Chinese than English, that

# %% [markdown]
# ### Bulgarian vs. Japanese students essays -- qualitative differences?
# - Any differences in content and style?

# %% [markdown]
# ### Basic corpus stats
# - size/length as word count
# - measurement per group and per individual essays

# %%
# corpus size in word count, average word count per essay
print('BU:', len(bucor.words()), len(bucor.words())/30)
print('JA:', len(jacor.words()), len(jacor.words())/30)
# Out:
# BU: 17326 577.5333333333333
# JA: 16094 536.4666666666667

# %%
# the same, but per-essay measurements
bucor_wordcount = [len(bucor.words(f)) for f in bucor.fileids()]
jacor_wordcount = [len(jacor.words(f)) for f in jacor.fileids()]
print('BU:', sorted(bucor_wordcount))
print('JA:', sorted(jacor_wordcount))
# Out:
# BU: [241, 360, 379, 405, 420, 421, 436, 451, 491, 498, 500, 503, 542, 548, 549, 578, 583, 598, 614, 624, 646, 647, 648, 655, 684, 702, 743, 809, 863, 1188]
# JA: [457, 464, 465, 472, 475, 478, 478, 492, 493, 495, 495, 501, 508, 512, 520, 548, 552, 554, 559, 565, 572, 573, 575, 579, 586, 589, 622, 630, 635, 650]

# %% [markdown]
# - How do we know these numbers are correct?
# - We should do: **spot checks**. But how?

# %% [markdown]
# ### More corpus stats
# - sentence counts and average sentence lengths (= # of words in sentence)
# - measurement per group and per individual essays

# %%
# corpus sentence counts, average sentence count per essay
print('BU:', len(bucor.sents()), len(bucor.sents())/30)
print('JA:', len(jacor.sents()), len(jacor.sents())/30)
# Out:
# BU: 745 24.833333333333332
# JA: 1027 34.233333333333334

# %%
# average sentence lengths in # of words
print('BU:', len(bucor.words())/len(bucor.sents()))
print('JA:', len(jacor.words())/len(jacor.sents()))
# Out:
# BU: 23.256375838926175
# JA: 15.670886075949367

# %%
# sentence count, but per-essay. 
bucor_sentcount = [len(bucor.sents(f)) for f in bucor.fileids()]
jacor_sentcount = [len(jacor.sents(f)) for f in jacor.fileids()]
print('BU:', sorted(bucor_sentcount))
print('JA:', sorted(jacor_sentcount))
# Out:
# BU: [12, 14, 15, 15, 16, 17, 18, 19, 21, 21, 22, 22, 23, 23, 23, 24, 26, 26, 26, 27, 27, 27, 28, 29, 31, 32, 33, 37, 37, 54]
# JA: [18, 20, 22, 23, 28, 28, 29, 30, 30, 33, 33, 34, 34, 34, 35, 35, 36, 36, 37, 37, 37, 39, 40, 40, 41, 42, 42, 43, 43, 48]

# %%
# sentence length, but per-essay measurements. Let's round 'em...
bucor_sentlen = [round(len(bucor.words(f))/len(bucor.sents(f)), 2) for f in bucor.fileids()]
jacor_sentlen = [round(len(jacor.words(f))/len(jacor.sents(f)), 2) for f in jacor.fileids()]
print('BU:', sorted(bucor_sentlen))
print('JA:', sorted(jacor_sentlen))
# Out:
# BU: [13.46, 15.06, 15.98, 17.51, 17.54, 17.71, 19.93, 20.19, 22.29, 22.29, 22.73, 23.62, 23.74, 23.83, 23.95, 23.96, 24.64, 25.19, 25.33, 25.35, 25.71, 26.0, 26.0, 27.28, 28.0, 28.58, 29.07, 33.75, 36.0, 38.52]
# JA: [11.24, 11.5, 11.79, 11.95, 12.09, 12.49, 12.69, 13.0, 13.66, 14.31, 14.94, 15.84, 15.89, 15.97, 16.12, 16.25, 16.4, 16.81, 16.85, 17.03, 17.55, 17.61, 17.85, 18.47, 20.18, 20.22, 21.59, 21.9, 22.85, 25.78]

# %%
import statistics
print('BU:', statistics.mean(bucor_sentlen), statistics.median(bucor_sentlen))
print('JA:', statistics.mean(jacor_sentlen), statistics.median(jacor_sentlen))
# Out:
# BU: 24.107 23.955
# JA: 16.360666666666667 16.185000000000002

# %% [markdown]
# - Again, how do we know these numbers are correct? Can we trust NLTK's sentence tokenization method? _HOW_ does it determine sentence boundaries...?
# - **spot checks**. Good candidates?

# %% [markdown]
# ### Word frequencies
# - Compile word frequency distributions for BU and JA groups, compare

# %%
bucor_fd = nltk.FreqDist([w.lower() for w in bucor.words()])
bucor_fd.most_common(50)
# Out:
# [('the', 808), (',', 768), ('.', 699), ('to', 510), ('of', 498), ('and', 456), ('in', 354), ('is', 339), ('a', 281), ('that', 250), ('it', 235), ('for', 193), ('not', 177), ('are', 167), ('they', 160), ('be', 143), ('have', 134), ('with', 123), ('-', 115), ('their', 110), ('i', 109), ('our', 105), ('we', 105), ('as', 102), ('one', 101), ('life', 99), ('"', 99), ('this', 96), ('people', 92), ('but', 81), ("'", 79), ('imagination', 77), ('university', 77), ('or', 74), ('you', 72), ('on', 67), ('world', 67), ('do', 66), ('all', 65), ('will', 65), ('has', 64), ('students', 60), ('which', 60), ('there', 60), ('what', 60), ('them', 56), ('so', 55), ('us', 55), ('more', 54), ('real', 51)]

# %%
jacor_fd = nltk.FreqDist([w.lower() for w in jacor.words()])
jacor_fd.most_common(50)
# Out:
# [('.', 997), ('english', 710), (',', 709), ('to', 590), ('i', 452), ('is', 413), ('the', 383), ('and', 323), ('in', 272), ('we', 271), ('a', 240), ('that', 203), ('of', 202), ('it', 189), ('japanese', 181), ('language', 180), ('master', 167), ('think', 165), ("'", 163), ('people', 154), ('can', 151), ('for', 151), ('as', 136), ('if', 126), ('speak', 123), ('t', 119), ('but', 115), ('so', 114), ('not', 112), ('are', 111), ('have', 109), ('many', 103), ('be', 102), ('world', 93), ('need', 91), ('with', 90), ('second', 90), ('more', 79), ('study', 78), ('japan', 74), ('students', 73), ('foreign', 71), ('use', 70), ('they', 70), ('because', 69), ('very', 64), ('or', 62), ('will', 62), ('at', 62), ('by', 59)]

# %% [markdown]
# - What jumps out at you?
# - Beyond eyeballing them for impressions, what can we do?
# - Any method for more robust comparisions?

# %% [markdown]
# ### Bigram frequencies
# - Compile bigram frequency distributions

# %%
bucor_2grams = nltk.ngrams([w.lower() for w in bucor.words()], 2)
bucor_2gram_fd = nltk.FreqDist(bucor_2grams)
bucor_2gram_fd.most_common(50)
# Out:
# [(('of', 'the'), 98), (('it', 'is'), 75), (('in', 'the'), 72), (('.', 'the'), 68), (('to', 'be'), 48), (('for', 'the'), 46), (("'", 's'), 44), ((',', 'the'), 42), (('.', 'it'), 40), ((',', 'it'), 40), (('do', 'not'), 38), (('to', 'the'), 37), (('is', 'the'), 35), ((',', 'and'), 33), (('life', '.'), 30), (('they', 'are'), 30), (('there', 'is'), 27), (('.', 'they'), 27), (('with', 'the'), 27), (('.', 'in'), 27), (('in', 'a'), 26), (('is', 'not'), 25), ((',', 'they'), 25), (('on', 'the'), 24), (('.', 'but'), 23), (('in', 'our'), 23), (('university', 'degrees'), 23), ((',', 'to'), 23), (('.', 'i'), 22), (('of', 'our'), 21), (('imagination', '.'), 21), (('real', 'life'), 21), (('to', 'do'), 21), ((',', 'in'), 21), (('it', '.'), 20), (('the', 'university'), 20), (('the', 'real'), 20), (('.', 'we'), 20), (('this', 'is'), 20), (('should', 'be'), 20), (('the', 'fact'), 19), (('fact', 'that'), 19), (('real', 'world'), 19), (('is', 'a'), 18), (('that', 'the'), 18), (('in', 'their'), 18), ((',', 'which'), 18), (('as', 'a'), 18), (('and', 'the'), 18), (('their', 'own'), 18)]

# %%
jacor_2grams = nltk.ngrams([w.lower() for w in jacor.words()], 2)
jacor_2gram_fd = nltk.FreqDist(jacor_2grams)
jacor_2gram_fd.most_common(50)
# Out:
# [(('.', 'i'), 152), (('i', 'think'), 137), (('master', 'english'), 128), (('english', 'is'), 125), (('english', '.'), 124), (('to', 'master'), 121), (("'", 't'), 119), (('it', 'is'), 110), ((',', 'i'), 90), (('speak', 'english'), 87), (('english', ','), 82), (('second', 'language'), 81), ((',', 'we'), 78), (('english', 'as'), 78), (('as', 'a'), 77), (('the', 'world'), 76), (('need', 'to'), 74), (('in', 'the'), 71), (('language', '.'), 70), (('a', 'second'), 68), (('.', 'if'), 59), (('think', 'that'), 58), (('if', 'we'), 57), (('japanese', 'students'), 56), (('we', 'can'), 54), (('.', 'so'), 51), (('.', 'and'), 50), (('.', 'but'), 49), (('.', 'it'), 46), ((',', 'and'), 43), (('able', 'to'), 43), (('want', 'to'), 42), (('study', 'english'), 40), (('.', 'in'), 40), (('can', "'"), 40), (('world', '.'), 40), (('use', 'english'), 38), (('is', 'very'), 38), (('to', 'speak'), 37), ((',', 'english'), 36), (('in', 'english'), 36), (('communicate', 'with'), 34), (('have', 'to'), 34), (('there', 'are'), 34), (('students', 'need'), 33), (('in', 'japan'), 33), (('don', "'"), 33), (("'", 's'), 33), (('to', 'study'), 32), ((',', 'it'), 31)]

# %% [markdown]
# - So... that's _interesting_!!
# - Beyond eyeballing them for impressions, what can we do?
# - Any method for more robust comparisions?

# %% [markdown]
# ### Indicators of writing quality. TTR: Type-Token Ratio
# - Type-token ratio (TTR) is a quick measurement for vocabulary diversity.
# - Per-group measurement and also per-essay measurement.
# - But there's a big caveat. What?

# %%
# per-group measurements
print('BU:', len(bucor_fd)/len(bucor.words()))
print('JA:', len(jacor_fd)/len(jacor.words()))
# Out:
# BU: 0.14914002077802146
# JA: 0.09295389586181185

# %%
def get_ttr(wlist):
    wlist_lower = [w.lower() for w in wlist]
    return round(len(set(wlist_lower))/len(wlist_lower), 4)

get_ttr('Rose is a rose is a rose is a rose'.split())
# Out:
# 0.3

# %%
bucor_ttr = [get_ttr(bucor.words(f)) for f in bucor.fileids()]
jacor_ttr = [get_ttr(jacor.words(f)) for f in jacor.fileids()]
print('BU:', sorted(bucor_ttr))
print('JA:', sorted(jacor_ttr))
# Out:
# BU: [0.3523, 0.3903, 0.4051, 0.4065, 0.4094, 0.4118, 0.4133, 0.4136, 0.4171, 0.4214, 0.4242, 0.428, 0.4297, 0.4343, 0.4354, 0.4366, 0.4426, 0.4489, 0.4524, 0.4562, 0.4625, 0.4712, 0.4719, 0.48, 0.4806, 0.4945, 0.4988, 0.504, 0.5046, 0.5768]
# JA: [0.2442, 0.2692, 0.2953, 0.2974, 0.2988, 0.3066, 0.3083, 0.3199, 0.3208, 0.3212, 0.3214, 0.3256, 0.3264, 0.3281, 0.3389, 0.3421, 0.3465, 0.3475, 0.3476, 0.3514, 0.3598, 0.3635, 0.3642, 0.3714, 0.3879, 0.4065, 0.41, 0.4242, 0.4424, 0.4486]

# %% [markdown]
# - OK, those are the numbers... but _how to interpret them_?
# - Also, the big CAVEAT? What do we do about it?

# %% [markdown]
# ### Indicators of writing quality. Average word length

# %%
def get_avg_wlen(wlist):
    wlen = [len(w) for w in wlist]
    return round(sum(wlen)/len(wlen), 2)

get_avg_wlen('Rose is a rose is a rose is a rose'.split())
# Out:
# 2.5

# %%
# per-group measurements
print('BU:', get_avg_wlen(bucor.words()))
print('JA:', get_avg_wlen(jacor.words()))
# Out:
# BU: 4.25
# JA: 4.03

# %%
bucor_wlen = [get_avg_wlen(bucor.words(f)) for f in bucor.fileids()]
jacor_wlen = [get_avg_wlen(jacor.words(f)) for f in jacor.fileids()]
print('BU:', sorted(bucor_wlen))
print('JA:', sorted(jacor_wlen))
# Out:
# BU: [3.61, 3.89, 3.92, 3.96, 4.0, 4.01, 4.02, 4.06, 4.07, 4.12, 4.15, 4.16, 4.2, 4.24, 4.24, 4.26, 4.32, 4.33, 4.4, 4.4, 4.4, 4.42, 4.47, 4.48, 4.5, 4.5, 4.51, 4.52, 4.55, 4.77]
# JA: [3.75, 3.77, 3.79, 3.84, 3.84, 3.86, 3.91, 3.92, 3.94, 3.95, 3.96, 3.97, 3.97, 3.99, 3.99, 4.03, 4.05, 4.05, 4.11, 4.11, 4.12, 4.13, 4.14, 4.16, 4.17, 4.17, 4.23, 4.27, 4.32, 4.48]

# %% [markdown]
# - That's it? What do these numbers _mean_?
# - What underlying factors could be driving the numbers lower? Higher?
# - Our method of calculating "average word length". Is this good? Any problem with it?

# %% [markdown]
# ## A Deeper Dive: Bringing in External Resources
# - Internal comparison between the Bulgarian and Japanese can take us only so far.
# - We should bring in external resources -- compiled from Native English writing -- for reference points.
# - Four resources:
#     - NLTK's stop words list: `nltk.corpus.stopwords`
#     - The "New General Service List" (NGSL 1.2) https://www.newgeneralservicelist.com/new-general-service-list
#     - The Inaugural Address corpus https://www.nltk.org/nltk_data/
#     - N-gram corpus data from Norvig (excerpted from Google 1T corpus) https://norvig.com/ngrams/

# %% [markdown]
# ### (1) NLTK's stopwords

# %%
from nltk.corpus import stopwords
stopw = stopwords.words('english')
stopw
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
'i' in stopw
# Out:
# True

# %%
len(stopw)
# Out:
# 198

# %%
[w for w in stopw if w not in bucor_fd and w not in jacor_fd]
# Out:
# ['ain', "aren't", 'below', "couldn't", "didn't", "doesn't", "don't", "hadn't", 'hasn', "hasn't", "haven't", "he'd", "he'll", 'hers', "he's", "i'd", "i'll", "i'm", "isn't", "it'd", "it'll", "it's", "i've", 'ma', 'mightn', "mightn't", "mustn't", 'needn', "needn't", 're', 'shan', "shan't", "she'd", "she'll", "she's", "shouldn't", "should've", "that'll", 'theirs', "they'd", "they'll", "they're", "they've", "wasn't", "we'd", "we'll", "we're", "weren't", "we've", "won't", "wouldn't", 'y', "you'd", "you'll", "you're", 'yours', 'yourselves', "you've"]

# %%
for w in stopw:
    if w not in bucor_fd and w not in jacor_fd: 
        pass
    else: 
        print(w, bucor_fd.freq(w), jacor_fd.freq(w), sep='\t')
# Out:
# a	0.016218400092346763	0.0149123897104511
# about	0.0010389010735311092	0.0028582080278364607
# above	0.0004617338104582708	0.0
# after	0.0008657508946092578	0.0008698893997763141
# again	0.00028858363153641927	0.00024853982850751833
# against	5.771672630728385e-05	6.213495712687958e-05
# all	0.0037515872099734503	0.003417422641978377
# am	0.0007503174419946901	0.0016155088852988692
# an	0.0024818192312132054	0.002796073070709581
# and	0.026318827196121435	0.020069591151982105
# any	0.0010966177998383933	0.000745619485522555
# are	0.009638693293316403	0.0068969802410836336
# aren	5.771672630728385e-05	0.00018640487138063875
# as	0.005887106083342953	0.008450354169255624
# at	0.0028281195890569088	0.003852367341866534
# be	0.008253491861941591	0.006337765626941718
# because	0.0018469352418330831	0.0042873120417546914
# been	0.0014429181576820962	0.0006834845283956755
# before	0.0009234676209165416	0.0006213495712687958
# being	0.001212051252452961	0.0003106747856343979
# between	0.0010389010735311092	0.0003106747856343979
# both	0.00028858363153641927	6.213495712687958e-05
# but	0.004675054830889992	0.007145520069591152
# by	0.0023663857785986377	0.0036659624704858955
# can	0.0025972526838277735	0.009382378526158816
# couldn	0.0	0.0008077544426494346
# d	5.771672630728385e-05	6.213495712687958e-05
# did	0.00028858363153641927	0.00012426991425375916
# didn	0.0	0.0003728097427612775
# do	0.0038093039362807344	0.0024232633279483036
# does	0.001212051252452961	0.00024853982850751833
# doesn	5.771672630728385e-05	0.0004970796570150367
# doing	0.00040401708415098696	0.00012426991425375916
# don	0.0002308669052291354	0.0020504535851870263
# down	0.0005771672630728385	6.213495712687958e-05
# during	0.00017315017892185154	0.00012426991425375916
# each	0.00028858363153641927	0.0008077544426494346
# few	0.0003463003578437031	0.0003106747856343979
# for	0.011139328177305783	0.009382378526158816
# from	0.0024818192312132054	0.0020504535851870263
# further	0.0002308669052291354	6.213495712687958e-05
# had	0.0013852014313748124	0.0008077544426494346
# hadn	0.0	0.00012426991425375916
# has	0.0036938704836661663	0.000745619485522555
# have	0.007734041325176036	0.006772710326829874
# haven	0.0	0.00012426991425375916
# having	0.0006348839893801224	0.00018640487138063875
# he	0.001154334526145677	0.0029203429849633403
# her	0.00028858363153641927	0.0004349446998881571
# here	0.0003463003578437031	6.213495712687958e-05
# herself	0.0001154334526145677	0.0
# him	0.00028858363153641927	0.0004970796570150367
# himself	0.00017315017892185154	0.00018640487138063875
# his	0.0019046519681403672	0.00024853982850751833
# how	0.0013852014313748124	0.0003106747856343979
# i	0.00629112316749394	0.02808500062134957
# if	0.002424102504905922	0.007829004597986827
# in	0.020431721112778484	0.016900708338511247
# into	0.0014429181576820962	0.0004970796570150367
# is	0.019565970218169224	0.02566173729340127
# isn	0.0002308669052291354	0.00012426991425375916
# it	0.013563430682211705	0.01174350689698024
# its	0.001558351610296664	6.213495712687958e-05
# itself	0.00017315017892185154	0.0
# just	0.0015006348839893802	0.0003728097427612775
# ll	0.0	0.00012426991425375916
# m	5.771672630728385e-05	0.0004970796570150367
# me	0.001154334526145677	0.001366969056791351
# more	0.003116703220593328	0.004908661613023487
# most	0.0020778021470622184	0.002112588542313906
# mustn	5.771672630728385e-05	6.213495712687958e-05
# my	0.0021932355996767865	0.003168882813470859
# myself	0.0001154334526145677	0.0003106747856343979
# no	0.0028858363153641924	0.0006213495712687958
# nor	5.771672630728385e-05	0.0
# not	0.010215860556389242	0.006959115198210513
# now	0.0009234676209165416	0.0018640487138063876
# o	0.0001154334526145677	0.00018640487138063875
# of	0.028742929701027358	0.012551261339629676
# off	0.0003463003578437031	0.0
# on	0.003867020662588018	0.0028582080278364607
# once	0.0006926007156874062	6.213495712687958e-05
# only	0.0021355188733695025	0.0022989934136945444
# or	0.004271037746739005	0.003852367341866534
# other	0.0013852014313748124	0.003417422641978377
# our	0.0060602562622648045	0.0021747234994407855
# ours	0.0002308669052291354	0.0
# ourselves	5.771672630728385e-05	0.00018640487138063875
# out	0.0015006348839893802	0.0004349446998881571
# over	0.0002308669052291354	0.0017397787995526283
# own	0.0014429181576820962	0.000745619485522555
# s	0.0025972526838277735	0.0021747234994407855
# same	0.00028858363153641927	0.0003728097427612775
# she	5.771672630728385e-05	0.0008077544426494346
# should	0.00225095232598407	0.0020504535851870263
# shouldn	0.0	6.213495712687958e-05
# so	0.0031744199469006117	0.0070833851124642725
# some	0.0017892185155257993	0.0014291040139182303
# such	0.0012697679787602447	0.0006213495712687958
# t	0.0009234676209165416	0.007394059898098671
# than	0.0017315017892185155	0.001366969056791351
# that	0.014429181576820964	0.012613396296756556
# the	0.04663511485628535	0.02379768857959488
# their	0.006348839893801223	0.0021747234994407855
# them	0.0032321366732078957	0.0015533739281719896
# themselves	0.0007503174419946901	0.00012426991425375916
# then	0.0008080341683019739	0.0009320243569031938
# there	0.003463003578437031	0.0032931527277246177
# these	0.0018469352418330831	0.001801913756679508
# they	0.009234676209165417	0.004349446998881571
# this	0.005540805725499249	0.0024853982850751833
# those	0.0006926007156874062	0.0004970796570150367
# through	0.0005194505367655546	0.00018640487138063875
# to	0.029435530416714765	0.03665962470485895
# too	0.0007503174419946901	0.00149123897104511
# under	0.00028858363153641927	6.213495712687958e-05
# until	0.0001154334526145677	0.0
# up	0.0014429181576820962	0.0006213495712687958
# ve	0.0002308669052291354	0.0
# very	0.0012697679787602447	0.003976637256120293
# was	0.002020085420754935	0.0028582080278364607
# wasn	0.0001154334526145677	0.00024853982850751833
# we	0.0060602562622648045	0.016838573381384368
# were	0.0008657508946092578	0.0009941593140300733
# weren	5.771672630728385e-05	0.0
# what	0.003463003578437031	0.0012426991425375916
# when	0.0018469352418330831	0.0030446128992170996
# where	0.0006348839893801224	0.00024853982850751833
# which	0.003463003578437031	0.0016776438424257487
# while	0.0006926007156874062	0.0
# who	0.0019046519681403672	0.003106747856343979
# whom	0.0001154334526145677	6.213495712687958e-05
# why	0.0008080341683019739	0.001180564185410712
# will	0.0037515872099734503	0.003852367341866534
# with	0.007099157335795914	0.005592146141419162
# won	0.0	0.00018640487138063875
# wouldn	5.771672630728385e-05	6.213495712687958e-05
# you	0.004155604294124437	0.003106747856343979
# your	0.001154334526145677	0.0003106747856343979
# yourself	0.00017315017892185154	6.213495712687958e-05

# %%
stopw_freq = dict()
for w in stopw:
    if w not in bucor_fd and w not in jacor_fd: 
        pass
    else: 
        stopw_freq[w] = (bucor_fd.freq(w), jacor_fd.freq(w), bucor_fd.freq(w) - jacor_fd.freq(w))
        # BU relative frequency, JA relative frequency, difference

# %%
stopw_freq['the']
# Out:
# (0.04663511485628535, 0.02379768857959488, 0.022837426276690474)

# %%
# %pprint
sorted(stopw_freq.items(), key= lambda x: x[1][2], reverse=True)[:20]
# stop words that are more heavily used by BU students
# Out:
# Pretty printing has been turned ON
# [('the', (0.04663511485628535, 0.02379768857959488, 0.022837426276690474)),
#  ('of', (0.028742929701027358, 0.012551261339629676, 0.016191668361397682)),
#  ('and', (0.026318827196121435, 0.020069591151982105, 0.006249236044139329)),
#  ('they', (0.009234676209165417, 0.004349446998881571, 0.0048852292102838455)),
#  ('their',
#   (0.006348839893801223, 0.0021747234994407855, 0.004174116394360438)),
#  ('our', (0.0060602562622648045, 0.0021747234994407855, 0.003885532762824019)),
#  ('in', (0.020431721112778484, 0.016900708338511247, 0.003531012774267237)),
#  ('not', (0.010215860556389242, 0.006959115198210513, 0.003256745358178729)),
#  ('this', (0.005540805725499249, 0.0024853982850751833, 0.003055407440424066)),
#  ('has', (0.0036938704836661663, 0.000745619485522555, 0.0029482509981436115)),
#  ('are', (0.009638693293316403, 0.0068969802410836336, 0.002741713052232769)),
#  ('no', (0.0028858363153641924, 0.0006213495712687958, 0.0022644867440953964)),
#  ('what', (0.003463003578437031, 0.0012426991425375916, 0.002220304435899439)),
#  ('be', (0.008253491861941591, 0.006337765626941718, 0.0019157262349998733)),
#  ('it', (0.013563430682211705, 0.01174350689698024, 0.0018199237852314643)),
#  ('that', (0.014429181576820964, 0.012613396296756556, 0.0018157852800644077)),
#  ('which',
#   (0.003463003578437031, 0.0016776438424257487, 0.0017853597360112823)),
#  ('for', (0.011139328177305783, 0.009382378526158816, 0.001756949651146967)),
#  ('them',
#   (0.0032321366732078957, 0.0015533739281719896, 0.0016787627450359061)),
#  ('his',
#   (0.0019046519681403672, 0.00024853982850751833, 0.0016561121396328489))]

# %%
sorted(stopw_freq.items(), key= lambda x: x[1][2])[:20]
# stop words that are more heavily used by JA students
# Out:
# [('i', (0.00629112316749394, 0.02808500062134957, -0.02179387745385563)),
#  ('we', (0.0060602562622648045, 0.016838573381384368, -0.010778317119119564)),
#  ('to', (0.029435530416714765, 0.03665962470485895, -0.007224094288144186)),
#  ('can', (0.0025972526838277735, 0.009382378526158816, -0.006785125842331043)),
#  ('t', (0.0009234676209165416, 0.007394059898098671, -0.006470592277182129)),
#  ('is', (0.019565970218169224, 0.02566173729340127, -0.006095767075232045)),
#  ('if', (0.002424102504905922, 0.007829004597986827, -0.0054049020930809055)),
#  ('so', (0.0031744199469006117, 0.0070833851124642725, -0.00390896516556366)),
#  ('very',
#   (0.0012697679787602447, 0.003976637256120293, -0.0027068692773600488)),
#  ('as', (0.005887106083342953, 0.008450354169255624, -0.002563248085912671)),
#  ('but', (0.004675054830889992, 0.007145520069591152, -0.00247046523870116)),
#  ('because',
#   (0.0018469352418330831, 0.0042873120417546914, -0.0024403767999216083)),
#  ('other',
#   (0.0013852014313748124, 0.003417422641978377, -0.002032221210603565)),
#  ('don',
#   (0.0002308669052291354, 0.0020504535851870263, -0.001819586679957891)),
#  ('about',
#   (0.0010389010735311092, 0.0028582080278364607, -0.0018193069543053515)),
#  ('more',
#   (0.003116703220593328, 0.004908661613023487, -0.0017919583924301589)),
#  ('he', (0.001154334526145677, 0.0029203429849633403, -0.0017660084588176632)),
#  ('over',
#   (0.0002308669052291354, 0.0017397787995526283, -0.0015089118943234928)),
#  ('by',
#   (0.0023663857785986377, 0.0036659624704858955, -0.0012995766918872578)),
#  ('who', (0.0019046519681403672, 0.003106747856343979, -0.001202095888203612))]

# %% [markdown]
# ### (2) NGSL 1.2
# - Which file to process? I've downloaded "4. NGSL 1.2 alphabetized and lemmatized for research", file name `NGSL_1.2_lemmatized_for_research.csv`
# - How to read in this data file? Rather than using fancy format-specific methods (like `csv` module), I'm going to use the plain-old file `read()` method.

# %%
with open('NGSL_1.2_lemmatized_for_research.csv') as f:
    ngsl_raw = f.read()
ngsl_raw[:500]     # this is a single, raw string
                   # starts with comment lines it looks like...?
# Out:
# '## This list is not for pedagogical purposes. This list is for research purposes to account\n## for the coverage of the word and all its possible word forms irrespective of meaning sense.\n## We look at each word as a string of letters and count the frequency of occurrence of the string\n## and its inflected forms. For example the gerund form of verbs are occasionally found in the plural.\n## Therefore all possible gerunds are pluralized even though the possibility of their occurrence\n## is very low'

# %%
print(ngsl_raw[:1200])
# actual word list starts after an empty line
# Out:
# ## This list is not for pedagogical purposes. This list is for research purposes to account
# ## for the coverage of the word and all its possible word forms irrespective of meaning sense.
# ## We look at each word as a string of letters and count the frequency of occurrence of the string
# ## and its inflected forms. For example the gerund form of verbs are occasionally found in the plural.
# ## Therefore all possible gerunds are pluralized even though the possibility of their occurrence
# ## is very low.
# ## This type of corpus analysis often has problems with homographs. In the NGSL
# ## these homographs will need further analysis on the part of the researcher. These homograph include:
# ## FOUND (past tense of FIND and FOUND establish)
# ## LEFT (past tense of LEAVE and direction)
# ## MINE (pronoun and coal MINE)
# ## ROSE (past tense of RISE and flower)
# ## WOUND (past tense of WIND and injury)
# ## Researchers will have to adjust the list according to the software they use.
# ## Please send us a message if you find any homographs we have missed or mistakes we have made.
#
# a,an
# abandon,abandons,abandoned,abandoning,abandonings
# ability,abilities
# able,abler,ablest,ables,abled,abling,ablings
# abortion,abor

# %%
ngsl_raw.index('\n\n')  # position of the empty line. 
                        # I'll have to remove all characters up to this position...
# Out:
# 1067

# %%
# splicing the string from the empty line
# print(ngsl_raw[1067:])

# %%
ngsl_words = ngsl_raw[1067:].split()

# %%
len(ngsl_words)
# Out:
# 2809

# %%
'the' in ngsl_words
# Out:
# True

# %%
ngsl_words[:10]  # oops, forgot about commas
# Out:
# ['a,an',
#  'abandon,abandons,abandoned,abandoning,abandonings',
#  'ability,abilities',
#  'able,abler,ablest,ables,abled,abling,ablings',
#  'abortion,abortions',
#  'about,abouts',
#  'above',
#  'abroad,abroads',
#  'absence,absences',
#  'absolute,absolutes']

# %%
# replace commas with ' ', then split
ngsl_words = ngsl_raw[1067:].replace(',', ' ').split()

# %%
# %pprint
ngsl_words  # 'TRUE' is in all caps... HUH.
# Out:
# Pretty printing has been turned OFF
# ['a', 'an', 'abandon', 'abandons', 'abandoned', 'abandoning', 'abandonings', 'ability', 'abilities', 'able', 'abler', 'ablest', 'ables', 'abled', 'abling', 'ablings', 'abortion', 'abortions', 'about', 'abouts', 'above', 'abroad', 'abroads', 'absence', 'absences', 'absolute', 'absolutes', 'absolutely', 'abstract', 'abstracts', 'abstracted', 'abstracting', 'abstractings', 'abuse', 'abuses', 'abused', 'abusing', 'abusings', 'academic', 'academics', 'academick', 'accept', 'accepts', 'accepted', 'accepting', 'acceptings', 'acceptable', 'acceptables', 'access', 'accesses', 'accessed', 'accessing', 'accessings', 'accident', 'accidents', 'accommodation', 'accommodations', 'accompany', 'accompanies', 'accompanied', 'accompanying', 'accompanyings', 'accomplish', 'accomplishes', 'accomplished', 'accomplishing', 'accomplishings', 'accord', 'accords', 'accorded', 'according', 'accordings', 'account', 'accounts', 'accounted', 'accounting', 'accountings', 'accurate', 'accuse', 'accuses', 'accused', 'accusing', 'accusings', 'achieve', 'achieves', 'achieved', 'achieving', 'achieveing', 'achieveings', 'achievement', 'achievements', 'acknowledge', 'acknowledges', 'acknowledged', 'acknowledging', 'acknowledgings', 'acquire', 'acquires', 'acquired', 'acquiring', 'acquirings', 'acquisition', 'acquisitions', 'across', 'act', 'acts', 'acted', 'acting', 'actings', 'action', 'actions', 'actioned', 'actioning', 'actionings', 'active', 'actives', 'activity', 'activities', 'actor', 'actors', 'actual', 'actuals', 'actually', 'ad', 'ads', 'adapt', 'adapts', 'adapted', 'adapting', 'adaptings', 'add', 'adds', 'added', 'adding', 'addings', 'addition', 'additions', 'additional', 'additionals', 'address', 'addresses', 'addressed', 'addressing', 'addressings', 'adequate', 'adjust', 'adjusts', 'adjusted', 'adjusting', 'adjustings', 'adjustment', 'adjustments', 'administration', 'administrations', 'admire', 'admires', 'admired', 'admiring', 'admirings', 'admit', 'admits', 'admited', 'admitting', 'admitted', 'adopt', 'adopts', 'adopted', 'adopting', 'adoptings', 'adult', 'adults', 'advance', 'advances', 'advanced', 'advancing', 'advanceing', 'advanceings', 'advantage', 'advantages', 'advantaged', 'advantaging', 'advantagings', 'adventure', 'adventures', 'adventured', 'adventuring', 'adventurings', 'advertise', 'advertises', 'advertised', 'advertising', 'advertize', 'advertizes', 'advertized', 'advertizing', 'advertizings', 'advertisement', 'advertisements', 'advertisment', 'advertisments', 'advice', 'advices', 'advise', 'advises', 'advised', 'advising', 'advisings', 'adviser', 'advisers', 'advocate', 'advocates', 'advocated', 'advocating', 'advocatings', 'affair', 'affairs', 'affect', 'affects', 'affected', 'affecting', 'affectings', 'afford', 'affords', 'afforded', 'affording', 'affordings', 'afraid', 'after', 'afternoon', 'afternoons', 'again', 'against', 'age', 'ages', 'aged', 'aging', 'ageing', 'ageings', 'agency', 'agencies', 'agenda', 'agendas', 'agent', 'agents', 'aggressive', 'ago', 'agree', 'agrees', 'agreed', 'agreeing', 'agreeings', 'agreement', 'agreements', 'agricultural', 'agriculturals', 'ahead', 'aid', 'aids', 'aided', 'aiding', 'aidings', 'aim', 'aims', 'aimed', 'aiming', 'aimings', 'air', 'airs', 'aired', 'airing', 'airings', 'aircraft', 'aircrafts', 'airline', 'airlines', 'alarm', 'alarms', 'alarmed', 'alarming', 'alarmings', 'album', 'albums', 'alcohol', 'alcohols', 'alive', 'all', 'alls', 'allege', 'alleges', 'alleged', 'alleging', 'allegings', 'allow', 'allows', 'allowed', 'allowing', 'allowings', 'ally', 'allies', 'allied', 'allying', 'allyings', 'almost', 'almosts', 'alone', 'along', 'alongside', 'already', 'alright', 'also', 'alter', 'alters', 'altered', 'altering', 'alterings', 'alternative', 'alternatives', 'although', 'altho', 'altogether', 'always', 'amaze', 'amazes', 'amazed', 'amazing', 'amazings', 'amendment', 'amendments', 'among', 'amount', 'amounts', 'amounted', 'amounting', 'amountings', 'analysis', 'analyses', 'analyst', 'analyst ...

# %%
[x for x in ngsl_words if not x.islower()]  # whoa...
# Out:
# ['FALSE', 'I', 'TRUE']

# %%
[w for w in stopw if w not in ngsl_words] # i, ma, and y
# Out:
# ["aren't", "couldn't", "didn't", "doesn't", 'don', "don't", "hadn't", "hasn't", "haven't", "he'd", "he'll", "he's", 'i', "i'd", "i'll", "i'm", "isn't", "it'd", "it'll", "it's", "i've", 'ma', "mightn't", "mustn't", "needn't", 'o', "shan't", "she'd", "she'll", "she's", "shouldn't", "should've", "that'll", "they'd", "they'll", "they're", "they've", "wasn't", "we'd", "we'll", "we're", "weren't", "we've", "won't", "wouldn't", 'y', "you'd", "you'll", "you're", "you've"]

# %%
'english' in ngsl_words  # hmm...
# Out:
# False

# %%
len(ngsl_words)
# Out:
# 10126

# %%
# Let's lowercase all NGSL words
ngsl_words = [w.lower() for w in ngsl_words]

# %%
myfile = 'BGSU1009.txt'    # ok, not so random
bu_random = bucor.words(myfile)
len(bu_random)
# NB: BGSU1009.txt gives interesting results
# Out:
# 420

# %%
bu_random[:100]
# Out:
# ['The', 'world', 'we', 'live', 'in', 'is', 'obsessed', 'with', 'the', 'achievements', 'of', 'science', ',', 'technology', 'and', 'industrialization', '.', 'The', 'modern', 'civilization', 'has', 'created', 'incommunicative', ',', 'impatient', ',', 'narrow', '-', 'minded', 'people', 'that', 'do', 'not', 'care', 'for', 'the', 'history', 'but', 'only', 'for', 'their', 'well', '-', 'being', '.', 'The', 'fact', 'is', 'that', 'we', 'have', 'ceased', 'to', 'be', 'spiritual', 'and', 'simple', 'beings', 'and', 'have', 'turned', 'into', 'too', 'practical', ',', 'down', '-', 'to', '-', 'earth', 'people', '.', 'That', 'is', 'why', 'there', 'is', 'no', 'longer', 'place', 'for', 'imagination', 'and', 'dreaming', 'in', 'our', 'present', 'life', '.', 'According', 'to', 'me', ',', 'the', 'modern', 'technologically', 'dominated', 'world', 'has', 'made']

# %%
ngsl_in = set([w for w in bu_random if w.lower() in ngsl_words])

# %%
ngsl_out = set([w for w in bu_random if w.lower() not in ngsl_words])

# %%
ngsl_in # word types in NGSL
# Out:
# {'earth', 'beautiful', 'talents', 'lead', 'dominated', 'the', 'between', 'these', 'old', 'do', 'imagination', 'speed', 'made', 'healthier', 'maybe', 'created', 'us', 'because', 'develop', 'generation', 'Those', 'are', 'And', 'complete', 'feel', 'has', 'set', 'intellectual', 'merely', 'themselves', 'but', 'Our', 'The', 'example', 'to', 'they', 'time', 'too', 'Let', 'keeping', 'by', 'science', 'gain', 'ideas', 'People', 'hate', 'dream', 'that', 'soul', 'fact', 'beginning', 'of', 'practical', 'modern', 'more', 'no', 'this', 'and', 'isolated', 'sense', 'minded', 'life', 'hours', 'desire', 'nature', 'respect', 'reading', 'According', 'technology', 'way', 'it', 's', 'achievements', 'turn', 'essential', 'ask', 'simple', 'is', 'relationship', 'educate', 'me', 'on', 'balance', 'be', 'turned', 'down', 'love', 'them', 'values', 'follow', 'comes', 'ready', 'encourages', 'nearer', 'not', 'for', 'encourage', 'understanding', 'More', 'need', 'young', 'thinking', 'order', 'connection', 'characteristic', 'vital', 'from', 'place', 'surround', 'well', 'their', 'being', 'will', 'true', 'people', 'our', 'a', 'history', 'age', 'positive', 'hope', 'Do', 'narrow', 'with', 'material', 'offering', 'live', 'human', 'only', 'longer', 'in', 'care', 'spend', 'than', 'all', 'satisfaction', 'really', 'lost', 'talks', 'each', 'why', 'there', 'dreaming', 'have', 'other', 'world', 'based', 'we', 'Nature', 'children', 'into', 'everyday', 'restored', 'closer', 'beings', 'images', 'I', 'animals', 'That', 'present', 'question', 'things', 'answer', 'contact', 'next', 'relationships'}

# %%
ngsl_out
# punctuation and seemingly high-level words... but 'happily'? 'TV'?
# Out:
# {'ceased', 'chaos', 'TV', 'commercialism', 'frieks', 'incommunicative', '"', '.', '-', 'impatient', 'materialism', 'obsessed', 'entrapped', ',', 'technologically', 'envy', 'desperate', 'dehumanize', 'industrialization', '?"', 'happily', 'deprived', 'helplessness', 'patience', "'", 'aspects', 'perfection', 'technological', 'civilization', 'glued', 'spiritual', 'negatively'}

# %%
print('ratio of in-NGSL word types:', len(ngsl_in)/len(set(bu_random)))
print('ratio of out-NGSL word types:', len(ngsl_out)/len(set(bu_random)))
# Out:
# ratio of in-NGSL word types: 0.8383838383838383
# ratio of out-NGSL word types: 0.16161616161616163

# %%
for f in bucor.fileids():
    ngsl_in = set([w for w in bucor.words(f) if w.lower() in ngsl_words])
    ngsl_out = set([w for w in bucor.words(f) if w.lower() not in ngsl_words])
    print(f, round(len(ngsl_in)/len(set(bucor.words(f))),4), 
          round(len(ngsl_out)/len(set(bucor.words(f))),4), sep="\t")
# Out:
# BGSU1001.txt	0.8885	0.1115
# BGSU1002.txt	0.9167	0.0833
# BGSU1003.txt	0.8234	0.1766
# BGSU1004.txt	0.8755	0.1245
# BGSU1005.txt	0.8683	0.1317
# BGSU1006.txt	0.9075	0.0925
# BGSU1007.txt	0.8527	0.1473
# BGSU1008.txt	0.8631	0.1369
# BGSU1009.txt	0.8384	0.1616
# BGSU1010.txt	0.9056	0.0944
# BGSU1011.txt	0.786	0.214
# BGSU1012.txt	0.8039	0.1961
# BGSU1013.txt	0.836	0.164
# BGSU1014.txt	0.8456	0.1544
# BGSU1015.txt	0.8653	0.1347
# BGSU1016.txt	0.9272	0.0728
# BGSU1017.txt	0.8213	0.1787
# BGSU1018.txt	0.8462	0.1538
# BGSU1019.txt	0.8522	0.1478
# BGSU1020.txt	0.8535	0.1465
# BGSU1021.txt	0.8739	0.1261
# BGSU1022.txt	0.9147	0.0853
# BGSU1023.txt	0.898	0.102
# BGSU1024.txt	0.8795	0.1205
# BGSU1025.txt	0.7697	0.2303
# BGSU1026.txt	0.8504	0.1496
# BGSU1027.txt	0.8537	0.1463
# BGSU1028.txt	0.8645	0.1355
# BGSU1029.txt	0.9409	0.0591
# BGSU1030.txt	0.9135	0.0865

# %%
# this one essay has the lowest NGSL coverage of 0.7697. 
# what out-NGSL words are they using...? 
f = 'BGSU1025.txt'
ngsl_in = set([w for w in bucor.words(f) if w.lower() in ngsl_words])
ngsl_out = set([w for w in bucor.words(f) if w.lower() not in ngsl_words])
print(ngsl_out)
# Out:
# {'sobers', 'decent', 'accumulate', 'pomising', 'stereotype', 'philosophers', 'industrialized', 'everu', 'dignified', 'validity', '"', 'pinpointed', 'scholarly', 'analogy', 'spings', 'recipients', 'thread', 'absurd', 'endeavouring', 'youngsters', 'denuded', 'builders', 'convincigly', 'Philology', 'Pope', 'miscast', 'fetched', "'", 'proclaiming', 'translator', 'fi', 'orientated', 'diplomas', 'chaos', 'strictly', 'watchersthey', 'rhyming', 'correspondence', 'echo', 'brims', 'practically', '?', 'overcharge', 'English', '-', 'institutionalized', 'te', 'imperial', 'Thirdly', 'idividuals', 'worldly', ',', 'compulsory', 'heartedly', 'compelled', 'incapable', 'ambitions', 'irrelevant', 'prosperous', '."', 'sphere', 'verse', '..', 'Alexander', 'teenage', 'ridiculousness', 'stern', 'stereotyped', 'shed', 'amusing', 'digest', 'lifeless', 'cherished', 'Dickens', 'recipe', 'Gradgrind', 'productive', 'Charles', 'intelletual', 'curriculum', 'martyrs', '.', 'barren', 'interpreter', 'exclusion', 'statistics', 'Phonology', 'Linguistics', 'reciting', 'Phonetics', ';', 'specialization', 'authoritative', 'mercilessly', 'passive', 'discrepancy', 'correctly', 'tutors', 'vowel', '1', 'Pierian', 'avail', 'Syntax', 'overshadowed', 'zealotry', 'mechanical', 'Thomas', 'sloppiness', 'shallow', 'Victorian', 'accumulation', 'two', 'unveiled', 'o', 'tragic', 'gallons', 'intoxicate', ':', 'media', 'beneficial'}

# %% [markdown]
# - 'zealotry', 'Syntax'... lots of fancy words! So this student is indeed using lots of high-level vocabs.

# %%
# this one has the highest NGSL coverage of 0.9409. 
# what out-NGSL words are they using...? 
f = 'BGSU1029.txt'
ngsl_in = set([w for w in bucor.words(f) if w.lower() in ngsl_words])
ngsl_out = set([w for w in bucor.words(f) if w.lower() not in ngsl_words])
print(ngsl_out)
# that's it, very few
# Out:
# {'diploma', '.', 'diplomas', 'practically', 'don', 'Bulgaria', 'aspects', "'", ',', '"', '-'}

# %%
for f in jacor.fileids():
    ngsl_in = set([w for w in jacor.words(f) if w.lower() in ngsl_words])
    ngsl_out = set([w for w in jacor.words(f) if w.lower() not in ngsl_words])
    print(f, round(len(ngsl_in)/len(set(jacor.words(f))),4), 
          round(len(ngsl_out)/len(set(jacor.words(f))),4), sep="\t")
# Out:
# JPSW1001.txt	0.9	0.1
# JPSW1002.txt	0.8918	0.1082
# JPSW1003.txt	0.8162	0.1838
# JPSW1004.txt	0.8889	0.1111
# JPSW1005.txt	0.8395	0.1605
# JPSW1006.txt	0.8276	0.1724
# JPSW1007.txt	0.8757	0.1243
# JPSW1008.txt	0.8889	0.1111
# JPSW1009.txt	0.8232	0.1768
# JPSW1010.txt	0.8521	0.1479
# JPSW1011.txt	0.8396	0.1604
# JPSW1012.txt	0.895	0.105
# JPSW1013.txt	0.8776	0.1224
# JPSW1014.txt	0.8526	0.1474
# JPSW1015.txt	0.8441	0.1559
# JPSW1016.txt	0.8808	0.1192
# JPSW1017.txt	0.9158	0.0842
# JPSW1018.txt	0.9013	0.0987
# JPSW1019.txt	0.9014	0.0986
# JPSW1020.txt	0.8756	0.1244
# JPSW1021.txt	0.8883	0.1117
# JPSW1022.txt	0.863	0.137
# JPSW1023.txt	0.884	0.116
# JPSW1024.txt	0.8978	0.1022
# JPSW1025.txt	0.8959	0.1041
# JPSW1026.txt	0.8939	0.1061
# JPSW1027.txt	0.8743	0.1257
# JPSW1028.txt	0.8827	0.1173
# JPSW1029.txt	0.8815	0.1185
# JPSW1030.txt	0.7948	0.2052

# %% [markdown]
# - OK, but how to interpret these numbers?
# - Does higher NGSL coverage mean lower writing quality or the other way around...?
# - What reasons could there be for a word type to be not in the NGSL list?
