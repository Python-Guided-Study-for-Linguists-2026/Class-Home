# %% [markdown]
# # Day 4: More NLTK and Corpus Tools
#
# Na-Rae Han (`naraehan@pitt.edu`)
#
# Based on tutorial from [NASSLLI 2018 at CMU](https://www.cmu.edu/nasslli2018/)
#
# Original tutorial is found on https://github.com/naraehan/NASSLLI2018-Corpus-Linguistics
# - Jump to: [Day 1](day1.ipynb), [Day 2](day2.ipynb), [Day 3](day3.ipynb), [Day 4](day4.ipynb), [Day 5](day5.ipynb)

# %% [markdown]
# ## Preparation
#
# - Import NLTK
# - Load up the Inaugural corpus.

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
corpus_root = './inaugural'  # Use your own userid; Mac users should omit C:
inaug = PlaintextCorpusReader(corpus_root, '.*txt')  # all files ending in 'txt'

# %%
# %pprint
inaug.fileids()
# Out:
# Pretty printing has been turned OFF
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-Adams.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Roosevelt.txt', '1937-Roosevelt.txt', '1941-Roosevelt.txt', '1945-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan.txt', '1985-Reagan.txt', '1989-Bush.txt', '1993-Clinton.txt', '1997-Clinton.txt', '2001-Bush.txt', '2005-Bush.txt', '2009-Obama.txt', '2013-Obama.txt', '2017-Trump.txt', '2021-Biden.txt', '2025-Trump.txt']

# %%
print(inaug.words()[:50])
# Out:
# ['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House', 'of', 'Representatives', ':', 'Among', 'the', 'vicissitudes', 'incident', 'to', 'life', 'no', 'event', 'could', 'have', 'filled', 'me', 'with', 'greater', 'anxieties', 'than', 'that', 'of', 'which', 'the', 'notification', 'was', 'transmitted', 'by', 'your', 'order', ',', 'and', 'received', 'on', 'the', '14th', 'day', 'of', 'the', 'present', 'month']

# %% [markdown]
# ## n-grams

# %%
chom = 'colorless green ideas sleep furiously'.split()
chom
# Out:
# ['colorless', 'green', 'ideas', 'sleep', 'furiously']

# %%
list(nltk.bigrams('colorless green ideas sleep furiously'))
# Out:
# [('c', 'o'), ('o', 'l'), ('l', 'o'), ('o', 'r'), ('r', 'l'), ('l', 'e'), ('e', 's'), ('s', 's'), ('s', ' '), (' ', 'g'), ('g', 'r'), ('r', 'e'), ('e', 'e'), ('e', 'n'), ('n', ' '), (' ', 'i'), ('i', 'd'), ('d', 'e'), ('e', 'a'), ('a', 's'), ('s', ' '), (' ', 's'), ('s', 'l'), ('l', 'e'), ('e', 'e'), ('e', 'p'), ('p', ' '), (' ', 'f'), ('f', 'u'), ('u', 'r'), ('r', 'i'), ('i', 'o'), ('o', 'u'), ('u', 's'), ('s', 'l'), ('l', 'y')]

# %%
nltk.bigrams(chom)
# fundtion returns a "generator" object: it is memory-efficient but won't let us take a peak
# Out:
# <generator object bigrams at 0x000002F386866340>

# %%
# generator object works well in a loop environment
for x in nltk.bigrams(chom):
    print(x)
# Out:
# ('colorless', 'green')
# ('green', 'ideas')
# ('ideas', 'sleep')
# ('sleep', 'furiously')

# %%
# Force it into a list type
list(nltk.bigrams(chom))
# Out:
# [('colorless', 'green'), ('green', 'ideas'), ('ideas', 'sleep'), ('sleep', 'furiously')]

# %%
# trigram function also available
list(nltk.trigrams(chom))
# Out:
# [('colorless', 'green', 'ideas'), ('green', 'ideas', 'sleep'), ('ideas', 'sleep', 'furiously')]

# %%
# let's build a bigram list of the entire inaugural corpus
inaug_bigrams = list(nltk.bigrams(inaug.words()))
inaug_bigrams[:10]
# Out:
# [('Fellow', '-'), ('-', 'Citizens'), ('Citizens', 'of'), ('of', 'the'), ('the', 'Senate'), ('Senate', 'and'), ('and', 'of'), ('of', 'the'), ('the', 'House'), ('House', 'of')]

# %%
# last 20 bigrams
inaug_bigrams[-20:]
# Out:
# [('.', 'Thank'), ('Thank', 'you'), ('you', 'all'), ('all', '.'), ('.', 'Thank'), ('Thank', 'you'), ('you', '.'), ('.', 'Thank'), ('Thank', 'you'), ('you', 'very'), ('very', 'much'), ('much', '.'), ('.', 'Thank'), ('Thank', 'you'), ('you', 'very'), ('very', 'much'), ('much', '.'), ('.', 'Thank'), ('Thank', 'you'), ('you', '.')]

# %%
inaug.raw()[-500:]
# Out:
# ' before.\n\nWe will not be conquered, we will not be intimidated, we will not be broken, and we will not fail. From this day on, the United States of America will be a free, sovereign, and independent nation.\n\nWe will stand bravely, we will live proudly, we will dream boldly, and nothing will stand in our way because we are Americans. The future is ours, and our golden age has just begun.\n\nThank you. God bless America. Thank you all. Thank you. Thank you very much. Thank you very much. Thank you.\n'

# %%
# What are the most frquent bigrams? 
inaug_bigrams_fd = nltk.FreqDist(inaug_bigrams)
inaug_bigrams_fd.most_common(30)
# Out:
# [(('of', 'the'), 1784), ((',', 'and'), 1378), (('in', 'the'), 766), (('to', 'the'), 716), (('of', 'our'), 635), (('.', 'The'), 606), (('.', 'We'), 564), (('and', 'the'), 470), ((',', 'the'), 393), (('.', 'It'), 357), ((',', 'but'), 342), ((',', 'we'), 321), (('by', 'the'), 320), (('to', 'be'), 318), (('for', 'the'), 301), (('of', 'a'), 266), (('the', 'people'), 259), (('.', 'I'), 245), (("'", 's'), 242), (('the', 'world'), 231), (('with', 'the'), 230), ((',', 'to'), 223), (('will', 'be'), 220), ((',', 'I'), 213), (('that', 'the'), 213), (('.', 'In'), 209), (('have', 'been'), 209), ((',', 'in'), 208), (('.', 'And'), 192), (('has', 'been'), 188)]

# %%
inaug_trigrams_fd = nltk.FreqDist(nltk.ngrams(inaug.words(), 3))
inaug_trigrams_fd.most_common(30)
# Out:
# [(('.', 'It', 'is'), 155), (('the', 'United', 'States'), 153), ((',', 'and', 'the'), 140), (('.', 'We', 'have'), 102), (('of', 'the', 'United'), 101), (('of', 'the', 'people'), 99), (('of', 'the', 'Government'), 75), (('.', 'We', 'will'), 75), (('.', 'We', 'are'), 68), (('of', 'the', 'world'), 66), (('the', 'world', '.'), 64), ((',', 'and', 'to'), 60), ((',', 'we', 'will'), 58), (('.', 'In', 'the'), 57), ((',', 'and', 'we'), 57), ((',', 'and', 'that'), 55), ((',', 'in', 'the'), 52), (('of', 'our', 'country'), 51), (('of', 'the', 'Union'), 48), (('of', 'our', 'people'), 48), (('as', 'well', 'as'), 47), (('the', 'people', ','), 47), (('of', 'the', 'country'), 47), ((',', 'and', 'in'), 46), (('the', 'world', ','), 46), ((',', 'it', 'is'), 45), (('.', 'Let', 'us'), 44), (('in', 'the', 'world'), 43), ((',', 'we', 'have'), 42), (('.', 'This', 'is'), 42)]

# %%
inaug_bigrams_fd[('of', 'the')]
# Out:
# 1784

# %%
# What functions are available with this object? 
dir(inaug_bigrams_fd)
# Out:
# ['B', 'N', 'Nr', '_N', '__add__', '__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__le__', '__len__', '__lt__', '__missing__', '__module__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__weakref__', '_cumulative_frequencies', '_keep_positive', 'clear', 'copy', 'elements', 'freq', 'fromkeys', 'get', 'hapaxes', 'items', 'keys', 'max', 'most_common', 'pformat', 'plot', 'pop', 'popitem', 'pprint', 'r_Nr', 'setdefault', 'subtract', 'tabulate', 'total', 'update', 'values']

# %%
# over 1% of all bigrams are 'of the'! 
inaug_bigrams_fd.freq(('of', 'the'))
# Out:
# 0.011417965374891996

# %% [markdown]
# ## Conditional frequency distribution: by preceding word
# - What are the most common words following 'shall'?
#   - 'shall' becomes the condition for the next word: conditional frequency distribution.
#   - Stats can be compiled from a list of bigrams (w1, w2).

# %%
# cfd is built from bigrams: a list of (w1, w2) 
inaug_bigrams_cfd = nltk.ConditionalFreqDist(inaug_bigrams)

# %%
# 'shall' as the w1 condition. Value is a FreqDist! 
inaug_bigrams_cfd['shall']
# Out:
# FreqDist({'be': 65, 'not': 19, 'have': 16, 'endeavor': 8, 'do': 5, 'never': 5, 'make': 5, 'strive': 5, 'take': 4, 'leave': 4, ...})

# %%
inaug_bigrams_cfd['shall']['not']
# Out:
# 19

# %%
# total count of 'shall'
inaug_bigrams_cfd['shall'].N()
# Out:
# 312

# %%
# likelihood of 'not' following 'shall' 
inaug_bigrams_cfd['shall'].freq('not')
# Out:
# 0.060897435897435896

# %%
inaug_bigrams_cfd['shall'].freq('be')
# Out:
# 0.20833333333333334

# %%
inaug_bigrams_cfd['shall'].most_common(10)
# Out:
# [('be', 65), ('not', 19), ('have', 16), ('endeavor', 8), ('do', 5), ('never', 5), ('make', 5), ('strive', 5), ('take', 4), ('leave', 4)]

# %% [markdown]
# #### What about word likelyhood BEFORE a word?
# - We must flip (w1, w2) to (w2, w1), so that the 2nd word is the CONDITION, and the 1st word is the OUTCOME

# %%
[(w2,w1) for (w1,w2) in inaug_bigrams[:10]]
# Out:
# [('-', 'Fellow'), ('Citizens', '-'), ('of', 'Citizens'), ('the', 'of'), ('Senate', 'the'), ('and', 'Senate'), ('of', 'and'), ('the', 'of'), ('House', 'the'), ('of', 'House')]

# %%
inaug_bigrams_rev_cfd = nltk.ConditionalFreqDist([(w2,w1) for (w1,w2) in inaug_bigrams])

# %%
inaug_bigrams_rev_cfd['shall']
# Out:
# FreqDist({'I': 96, 'we': 48, 'We': 24, 'it': 11, ',': 11, 'which': 9, 'he': 7, 'and': 7, 'they': 4, 'revenue': 3, ...})

# %%
inaug_bigrams_cfd['the'].most_common(30)
# Out:
# [('people', 259), ('world', 231), ('United', 164), ('Constitution', 147), ('Government', 143), ('public', 91), ('Union', 88), ('great', 87), ('most', 85), ('same', 83), ('States', 77), ('country', 68), ('whole', 62), ('nation', 57), ('best', 56), ('American', 55), ('future', 50), ('first', 47), ('laws', 45), ('Executive', 44), ('other', 43), ('rights', 43), ('Federal', 43), ('spirit', 41), ('right', 41), ('power', 41), ('law', 40), ('principles', 38), ('present', 36), ('greatest', 32)]

# %%
inaug_bigrams_rev_cfd['the'].most_common(30)
# Out:
# [('of', 1784), ('in', 766), ('to', 716), ('and', 470), (',', 393), ('by', 320), ('for', 301), ('with', 230), ('that', 213), ('is', 183), ('on', 173), ('from', 158), ('all', 141), ('upon', 103), ('as', 95), ('at', 84), ('which', 83), ('under', 71), ('In', 61), ('be', 57), (';', 54), ('are', 43), ('between', 39), ('among', 39), ('when', 38), ('against', 37), ('not', 36), ('within', 36), ('or', 34), ('but', 34)]

# %% [markdown]
# #### How about characters? What characters are most likely to follow 't'?

# %%
inaug_charbigrams = list(nltk.bigrams(inaug.raw()))
inaug_charbigrams[:20]
# Out:
# [('F', 'e'), ('e', 'l'), ('l', 'l'), ('l', 'o'), ('o', 'w'), ('w', '-'), ('-', 'C'), ('C', 'i'), ('i', 't'), ('t', 'i'), ('i', 'z'), ('z', 'e'), ('e', 'n'), ('n', 's'), ('s', ' '), (' ', 'o'), ('o', 'f'), ('f', ' '), (' ', 't'), ('t', 'h')]

# %%
inaug_charbigrams_cfd = nltk.ConditionalFreqDist(inaug_charbigrams)
inaug_charbigrams_cfd['t']
# Out:
# FreqDist({'h': 18822, ' ': 12288, 'i': 8127, 'o': 5813, 'e': 5411, 'a': 2507, 'r': 2399, 's': 2033, 'y': 1716, 'u': 1361, ...})

# %%
inaug_charbigrams_cfd['t'].most_common()
# Out:
# [('h', 18822), (' ', 12288), ('i', 8127), ('o', 5813), ('e', 5411), ('a', 2507), ('r', 2399), ('s', 2033), ('y', 1716), ('u', 1361), (',', 672), ('t', 589), ('.', 517), ('l', 429), ('w', 179), ('m', 141), ('n', 64), ('c', 57), ('f', 56), (';', 52), ("'", 23), ('?', 21), (':', 14), ('p', 11), ('-', 10), ('g', 7), ('’', 5), ('b', 4), ('\n', 2), ('"', 2), ('—', 2), (')', 1), ('!', 1)]

# %%
inaug_charbigrams_cfd['q']
# Out:
# FreqDist({'u': 640, ' ': 1})

# %% [markdown]
# ## Conditional frequency distribution: count per year
# - Are words such as 'freedom', 'liberty', 'god' more frequent or less over time?
# - We will try out NLTK's book chapter on the Inaugural corpus: http://www.nltk.org/book/ch02.html#inaugural-address-corpus
#
# **Plotting/visualization**
# - If plotting breaks on you, matplotlib is not installed. Install it via `!pip install matplotlib`.
# - If plot graphs are too small, you can:
# ```
# import matplotlib.pyplot as plt
# plt.figure(figsize=(20,10))
# cfd.plot()
# ```

# %% [markdown]
# ## nltk.Text object and other corpus tools
# - NLTK's Text object class provides a concordancer and other classic corpus tools
# - A Text object can be built from a token list

# %%
inaug_Text = nltk.Text(inaug.words())
inaug_Text.concordance("shall")
# try "women", "men"
# Out:
# Displaying 25 of 316 matches:
# ur consideration such measures as he shall judge necessary and expedient ." The
# ived from official opportunities , I shall again give way to my entire confiden
# ccasion which brings us together , I shall take my present leave ; but not with
# te . When the occasion proper for it shall arrive , I shall endeavor to express
# asion proper for it shall arrive , I shall endeavor to express the high sense I
#  , and in your presence : That if it shall be found during my administration of
# determination to support it until it shall be altered by the judgments and wish
# es and the public opinion , until it shall be otherwise ordained by Congress ;
# gree to comply with your wishes , it shall be my strenuous endeavor that this s
# gacious injunction of the two Houses shall not be without effect . With this gr
# ities provided by our Constitution I shall find resources of wisdom , of virtue
# a wise and frugal Government , which shall restrain men from injuring one anoth
# rain men from injuring one another , shall leave them otherwise free to regulat
# ts of industry and improvement , and shall not take from the mouth of labor the
# l administration of your affairs . I shall often go wrong through defect of jud
#  defect of judgment . When right , I shall often be thought wrong by those whos
# ts , it will replace the advances we shall have made . I know that the acquisit
#  the benefit of all its strength . I shall now enter on the duties to which my
#  citizens have again called me , and shall proceed in the spirit of those princ
# imes injurious to your interests . I shall need , therefore , all the indulgenc
# not lessen with increasing years . I shall need , too , the favor of that Being
# eir measures that whatsoever they do shall result in your good , and shall secu
# y do shall result in your good , and shall secure to you the peace , friendship
# he intercourse between the States we shall add much to the convenience and comf
# , what is of greater importance , we shall shorten distances , and , by making

# %%
help(inaug_Text.concordance)
# Out:
# Help on method concordance in module nltk.text:
#
# concordance(word, width=79, lines=25) method of nltk.text.Text instance
#     Prints a concordance for ``word`` with the specified context window.
#     Word matching is not case-sensitive.
#
#     :param word: The target word or phrase (a list of strings)
#     :type word: str or list
#     :param width: The width of each line, in characters (default=80)
#     :type width: int
#     :param lines: The number of lines to display (default=25)
#     :type lines: int
#
#     :seealso: ``ConcordanceIndex``

# %%
# What other handy functions are available? 
dir(inaug_Text)
# Out:
# ['_CONTEXT_RE', '_COPY_TOKENS', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_concordance_index', '_context', '_train_default_ngram_lm', 'collocation_list', 'collocations', 'common_contexts', 'concordance', 'concordance_list', 'count', 'dispersion_plot', 'findall', 'generate', 'index', 'name', 'plot', 'readability', 'similar', 'tokens', 'vocab']

# %%
# Collocations found in this corpus. Try window size of 3. 
inaug_Text.collocations(20, 3)
# Out:
# United States; fellow citizens; men women; years ago; four years; Vice
# President; Federal Government; General Government; self government;
# American people; God bless; Chief Justice; every citizen; one another;
# fellow Americans; Fellow citizens; Old World; Almighty God; Chief
# Magistrate; Declaration Independence

# %%
# More info on the method. Doesn't say what stats are used...
help(inaug_Text.collocations)
# Out:
# Help on method collocations in module nltk.text:
#
# collocations(num=20, window_size=2) method of nltk.text.Text instance
#     Print collocations derived from the text, ignoring stopwords.
#
#         >>> from nltk.book import text4
#         >>> text4.collocations() # doctest: +NORMALIZE_WHITESPACE
#         United States; fellow citizens; years ago; four years; Federal
#         Government; General Government; American people; Vice President; God
#         bless; Chief Justice; one another; fellow Americans; Old World;
#         Almighty God; Fellow citizens; Chief Magistrate; every citizen; Indian
#         tribes; public debt; foreign nations
#
#
#     :param num: The maximum number of collocations to print.
#     :type num: int
#     :param window_size: The number of tokens spanned by a collocation (default=2)
#     :type window_size: int

# %%
# common context (surrounding words) shared by a list of words
inaug_Text.common_contexts(['shall', 'will'])
# Out:
# it_be i_be i_not we_be we_not we_strive we_have we_never we_do i_do
# we_find i_always they_not ,_we that_be revenue_be i_zealously i_never
# laws_be this_be

# %%
inaug_Text.generate()
# Out:
# Building ngram index...
# nucleus around which in their remote and isolated condition , but of a
# continent are made for the security and welfare of the Old World . ,
# resolution , or one that increases our wealth . constant embarrassment
# to the best , and , as now , that no heart but my own qualifications
# will teach me to this day into the Declaration of Independence was
# first honored with a respect for law , the purity of official
# negligence , and our counsel to the people . a multitude defined by
# any European Government that in the Executive power in
# 'nucleus around which in their remote and isolated condition , but of a\ncontinent are made for the security and welfare of the Old World . ,\nresolution , or one that increases our wealth . constant embarrassment\nto the best , and , as now , that no heart but my own qualifications\nwill teach me to this day into the Declaration of Independence was\nfirst honored with a respect for law , the purity of official\nnegligence , and our counsel to the people . a multitude defined by\nany European Government that in the Executive power in'

# %%
help(inaug_Text.generate)
# Out:
# Help on method generate in module nltk.text:
#
# generate(length=100, text_seed=None, random_seed=42) method of nltk.text.Text instance
#     Print random text, generated using a trigram language model.
#     See also `help(nltk.lm)`.
#
#     :param length: The length of text to generate (default=100)
#     :type length: int
#
#     :param text_seed: Generation can be conditioned on preceding context.
#     :type text_seed: list(str)
#
#     :param random_seed: A random seed or an instance of `random.Random`. If provided,
#         makes the random sampling part of generation reproducible. (default=42)
#     :type random_seed: int

# %%
inaug_Text.generate(length=100, text_seed=('We', 'must'), random_seed=20)
# Out:
# We must support our rights without human liberty . adjust to changing times
# and still more that is heading toward Mars . use our enormous powers
# to be only a tiny fraction of the majority should govern , we are to
# come . think big and dream even bigger . provide opportunity , we
# enthusiastically join with the chance to look toward me , with a
# patience and gentleness not born of bigotry or discrimination . do
# what we believe that the Federal law . realize that free speech ,
# freedom of all races and colors and creeds , could not see
# 'We must support our rights without human liberty . adjust to changing times\nand still more that is heading toward Mars . use our enormous powers\nto be only a tiny fraction of the majority should govern , we are to\ncome . think big and dream even bigger . provide opportunity , we\nenthusiastically join with the chance to look toward me , with a\npatience and gentleness not born of bigotry or discrimination . do\nwhat we believe that the Federal law . realize that free speech ,\nfreedom of all races and colors and creeds , could not see'
